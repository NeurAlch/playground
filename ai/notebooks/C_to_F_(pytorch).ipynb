# %%
import torch
import numpy as np
import pandas as pd
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
df = pd.read_csv('data.csv')

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))
# Out:
# Using cpu device

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()    
        self.layer_1 = nn.Sequential(
            nn.Linear(1, 1)            
        )      

    def forward(self, x):                
        logits = self.layer_1(x)
        return logits

# %%
model = NeuralNetwork().to(device)

# %%
print(model)
# Out:
# NeuralNetwork(
#   (layer_1): Sequential(
#     (0): Linear(in_features=1, out_features=1, bias=True)
#   )
# )

# %%
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

# %%
X_train = df['Celsius']
Y_train = df['Fahrenheit']

# %%
train_target = torch.tensor(Y_train.values.astype(np.float32))
train = torch.tensor(X_train.values.astype(np.float32)) 
train_tensor = TensorDataset(train, train_target) 
train_loader = DataLoader(dataset=train_tensor, batch_size=1, shuffle=True)

for X, y in train_loader:
    print("Shape of X: ", X.shape, X.dtype)
    print("Shape of y: ", y.shape, y.dtype)
    break
# Out:
# Shape of X:  torch.Size([1]) torch.float32
# Shape of y:  torch.Size([1]) torch.float32

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)

    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)        

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad() # set the gradients to zero before backpropragation
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)            
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
epochs = 450

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_loader, model, loss_fn, optimizer)

print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 6654.540039  [    0/   30]
# Epoch 2
# -------------------------------
# loss: 7745.439453  [    0/   30]
# Epoch 3
# -------------------------------
# loss: 960.685608  [    0/   30]
# Epoch 4
# -------------------------------
# loss: 1119.469482  [    0/   30]
# Epoch 5
# -------------------------------
# loss: 1372.439575  [    0/   30]
# Epoch 6
# -------------------------------
# loss: 67.671875  [    0/   30]
# Epoch 7
# -------------------------------
# loss: 5169.294434  [    0/   30]
# Epoch 8
# -------------------------------
# loss: 1001.439880  [    0/   30]
# Epoch 9
# -------------------------------
# loss: 1309.217651  [    0/   30]
# Epoch 10
# -------------------------------
# loss: 778.029297  [    0/   30]
# Epoch 11
# -------------------------------
# loss: 748.916077  [    0/   30]
# Epoch 12
# -------------------------------
# loss: 656.428711  [    0/   30]
# Epoch 13
# -------------------------------
# loss: 731.711731  [    0/   30]
# Epoch 14
# -------------------------------
# loss: 739.039856  [    0/   30]
# Epoch 15
# -------------------------------
# loss: 1625.643066  [    0/   30]
# Epoch 16
# -------------------------------
# loss: 1064.051636  [    0/   30]
# Epoch 17
# -------------------------------
# loss: 835.305908  [    0/   30]
# Epoch 18
# -------------------------------
# loss: 1381.519165  [    0/   30]
# Epoch 19
# -------------------------------
# loss: 1158.386108  [    0/   30]
# Epoch 20
# -------------------------------
# loss: 1425.064209  [    0/   30]
# Epoch 21
# -------------------------------
# loss: 934.410461  [    0/   30]
# Epoch 22
# -------------------------------
# loss: 794.879089  [    0/   30]
# Epoch 23
# -------------------------------
# loss: 877.524475  [    0/   30]
# Epoch 24
# -------------------------------
# loss: 821.610901  [    0/   30]
# Epoch 25
# -------------------------------
# loss: 1247.152588  [    0/   30]
# Epoch 26
# -------------------------------
# loss: 745.273071  [    0/   30]
# Epoch 27
# -------------------------------
# loss: 1079.307373  [    0/   30]
# Epoch 28
# -------------------------------
# loss: 760.794128  [    0/   30]
# Epoch 29
# -------------------------------
# loss: 782.547607  [    0/   30]
# Epoch 30
# -------------------------------
# loss: 735.228271  [    0/   30]
# Epoch 31
# -------------------------------
# loss: 756.127380  [    0/   30]
# Epoch 32
# -------------------------------
# loss: 763.770935  [    0/   30]
# Epoch 33
# -------------------------------
# loss: 734.326416  [    0/   30]
# Epoch 34
# -------------------------------
# loss: 721.914612  [    0/   30]
# Epoch 35
# -------------------------------
# loss: 665.038391  [    0/   30]
# Epoch 36
# -------------------------------
# loss: 719.086304  [    0/   30]
# Epoch 37
# -------------------------------
# loss: 787.056946  [    0/   30]
# Epoch 38
# -------------------------------
# loss: 752.675110  [    0/   30]
# Epoch 39
# -------------------------------
# loss: 636.081360  [    0/   30]
# Epoch 40
# -------------------------------
# loss: 666.943787  [    0/   30]
# Epoch 41
# -------------------------------
# loss: 692.507568  [    0/   30]
# Epoch 42
# -------------------------------
# loss: 566.882385  [    0/   30]
# Epoch 43
# -------------------------------
# loss: 681.677063  [    0/   30]
# Epoch 44
# -------------------------------
# loss: 827.139038  [    0/   30]
# Epoch 45
# -------------------------------
# loss: 584.906921  [    0/   30]
# Epoch 46
# -------------------------------
# loss: 570.990356  [    0/   30]
# Epoch 47
# -------------------------------
# loss: 794.729553  [    0/   30]
# Epoch 48
# -------------------------------
# loss: 754.198853  [    0/   30]
# Epoch 49
# -------------------------------
# loss: 645.909363  [    0/   30]
# Epoch 50
# -------------------------------
# loss: 584.683594  [    0/   30]
# Epoch 51
# -------------------------------
# loss: 570.192444  [    0/   30]
# Epoch 52
# -------------------------------
# loss: 576.792725  [    0/   30]
# Epoch 53
# -------------------------------
# loss: 354.892853  [    0/   30]
# Epoch 54
# -------------------------------
# loss: 789.818726  [    0/   30]
# Epoch 55
# -------------------------------
# loss: 558.611145  [    0/   30]
# Epoch 56
# -------------------------------
# loss: 566.109375  [    0/   30]
# Epoch 57
# -------------------------------
# loss: 560.145325  [    0/   30]
# Epoch 58
# -------------------------------
# loss: 650.215271  [    0/   30]
# Epoch 59
# -------------------------------
# loss: 528.126648  [    0/   30]
# Epoch 60
# -------------------------------
# loss: 550.409973  [    0/   30]
# Epoch 61
# -------------------------------
# loss: 539.719971  [    0/   30]
# Epoch 62
# -------------------------------
# loss: 348.391083  [    0/   30]
# Epoch 63
# -------------------------------
# loss: 520.826965  [    0/   30]
# Epoch 64
# -------------------------------
# loss: 550.034912  [    0/   30]
# Epoch 65
# -------------------------------
# loss: 557.562073  [    0/   30]
# Epoch 66
# -------------------------------
# loss: 616.998901  [    0/   30]
# Epoch 67
# -------------------------------
# loss: 480.218292  [    0/   30]
# Epoch 68
# -------------------------------
# loss: 491.704376  [    0/   30]
# Epoch 69
# -------------------------------
# loss: 278.769379  [    0/   30]
# Epoch 70
# -------------------------------
# loss: 470.621124  [    0/   30]
# Epoch 71
# -------------------------------
# loss: 455.888733  [    0/   30]
# Epoch 72
# -------------------------------
# loss: 488.522247  [    0/   30]
# Epoch 73
# -------------------------------
# loss: 486.095642  [    0/   30]
# Epoch 74
# -------------------------------
# loss: 453.032715  [    0/   30]
# Epoch 75
# -------------------------------
# loss: 600.718872  [    0/   30]
# Epoch 76
# -------------------------------
# loss: 439.734802  [    0/   30]
# Epoch 77
# -------------------------------
# loss: 472.484467  [    0/   30]
# Epoch 78
# -------------------------------
# loss: 465.787354  [    0/   30]
# Epoch 79
# -------------------------------
# loss: 515.926331  [    0/   30]
# Epoch 80
# -------------------------------
# loss: 454.554901  [    0/   30]
# Epoch 81
# -------------------------------
# loss: 271.224762  [    0/   30]
# Epoch 82
# -------------------------------
# loss: 404.546997  [    0/   30]
# Epoch 83
# -------------------------------
# loss: 574.120667  [    0/   30]
# Epoch 84
# -------------------------------
# loss: 354.566681  [    0/   30]
# Epoch 85
# -------------------------------
# loss: 286.154938  [    0/   30]
# Epoch 86
# -------------------------------
# loss: 229.830566  [    0/   30]
# Epoch 87
# -------------------------------
# loss: 439.899689  [    0/   30]
# Epoch 88
# -------------------------------
# loss: 374.795746  [    0/   30]
# Epoch 89
# -------------------------------
# loss: 418.829651  [    0/   30]
# Epoch 90
# -------------------------------
# loss: 414.204041  [    0/   30]
# Epoch 91
# -------------------------------
# loss: 486.615906  [    0/   30]
# Epoch 92
# -------------------------------
# loss: 218.191574  [    0/   30]
# Epoch 93
# -------------------------------
# loss: 371.682983  [    0/   30]
# Epoch 94
# -------------------------------
# loss: 535.954346  [    0/   30]
# Epoch 95
# -------------------------------
# loss: 347.938110  [    0/   30]
# Epoch 96
# -------------------------------
# loss: 463.772491  [    0/   30]
# Epoch 97
# -------------------------------
# loss: 341.144043  [    0/   30]
# Epoch 98
# -------------------------------
# loss: 377.883881  [    0/   30]
# Epoch 99
# -------------------------------
# loss: 202.323883  [    0/   30]
# Epoch 100
# -------------------------------
# loss: 477.075104  [    0/   30]
# Epoch 101
# -------------------------------
# loss: 428.581482  [    0/   30]
# Epoch 102
# -------------------------------
# loss: 488.711121  [    0/   30]
# Epoch 103
# -------------------------------
# loss: 330.995605  [    0/   30]
# Epoch 104
# -------------------------------
# loss: 336.303192  [    0/   30]
# Epoch 105
# -------------------------------
# loss: 239.880478  [    0/   30]
# Epoch 106
# -------------------------------
# loss: 430.686462  [    0/   30]
# Epoch 107
# -------------------------------
# loss: 334.540741  [    0/   30]
# Epoch 108
# -------------------------------
# loss: 322.380585  [    0/   30]
# Epoch 109
# -------------------------------
# loss: 324.984436  [    0/   30]
# Epoch 110
# -------------------------------
# loss: 308.436035  [    0/   30]
# Epoch 111
# -------------------------------
# loss: 283.534149  [    0/   30]
# Epoch 112
# -------------------------------
# loss: 431.090790  [    0/   30]
# Epoch 113
# -------------------------------
# loss: 272.735138  [    0/   30]
# Epoch 114
# -------------------------------
# loss: 410.817078  [    0/   30]
# Epoch 115
# -------------------------------
# loss: 277.905243  [    0/   30]
# Epoch 116
# -------------------------------
# loss: 189.990997  [    0/   30]
# Epoch 117
# -------------------------------
# loss: 208.564346  [    0/   30]
# Epoch 118
# -------------------------------
# loss: 200.144608  [    0/   30]
# Epoch 119
# -------------------------------
# loss: 332.752502  [    0/   30]
# Epoch 120
# -------------------------------
# loss: 252.013626  [    0/   30]
# Epoch 121
# -------------------------------
# loss: 250.322968  [    0/   30]
# Epoch 122
# -------------------------------
# loss: 371.630096  [    0/   30]
# Epoch 123
# -------------------------------
# loss: 143.908096  [    0/   30]
# Epoch 124
# -------------------------------
# loss: 264.832886  [    0/   30]
# Epoch 125
# -------------------------------
# loss: 204.016098  [    0/   30]
# Epoch 126
# -------------------------------
# loss: 255.970886  [    0/   30]
# Epoch 127
# -------------------------------
# loss: 217.860596  [    0/   30]
# Epoch 128
# -------------------------------
# loss: 243.067047  [    0/   30]
# Epoch 129
# -------------------------------
# loss: 281.001495  [    0/   30]
# Epoch 130
# -------------------------------
# loss: 146.847305  [    0/   30]
# Epoch 131
# -------------------------------
# loss: 221.745026  [    0/   30]
# Epoch 132
# -------------------------------
# loss: 276.590820  [    0/   30]
# Epoch 133
# -------------------------------
# loss: 229.251465  [    0/   30]
# Epoch 134
# -------------------------------
# loss: 218.105164  [    0/   30]
# Epoch 135
# -------------------------------
# loss: 258.873505  [    0/   30]
# Epoch 136
# -------------------------------
# loss: 170.742432  [    0/   30]
# Epoch 137
# -------------------------------
# loss: 201.828278  [    0/   30]
# Epoch 138
# -------------------------------
# loss: 198.307037  [    0/   30]
# Epoch 139
# -------------------------------
# loss: 228.325485  [    0/   30]
# Epoch 140
# -------------------------------
# loss: 196.992523  [    0/   30]
# Epoch 141
# -------------------------------
# loss: 132.866104  [    0/   30]
# Epoch 142
# -------------------------------
# loss: 107.317917  [    0/   30]
# Epoch 143
# -------------------------------
# loss: 171.493637  [    0/   30]
# Epoch 144
# -------------------------------
# loss: 103.691284  [    0/   30]
# Epoch 145
# -------------------------------
# loss: 168.603745  [    0/   30]
# Epoch 146
# -------------------------------
# loss: 228.634094  [    0/   30]
# Epoch 147
# -------------------------------
# loss: 163.529388  [    0/   30]
# Epoch 148
# -------------------------------
# loss: 168.937714  [    0/   30]
# Epoch 149
# -------------------------------
# loss: 160.302689  [    0/   30]
# Epoch 150
# -------------------------------
# loss: 149.825119  [    0/   30]
# Epoch 151
# -------------------------------
# loss: 155.865189  [    0/   30]
# Epoch 152
# -------------------------------
# loss: 164.542511  [    0/   30]
# Epoch 153
# -------------------------------
# loss: 155.639648  [    0/   30]
# Epoch 154
# -------------------------------
# loss: 153.484512  [    0/   30]
# Epoch 155
# -------------------------------
# loss: 144.940536  [    0/   30]
# Epoch 156
# -------------------------------
# loss: 205.970413  [    0/   30]
# Epoch 157
# -------------------------------
# loss: 134.806992  [    0/   30]
# Epoch 158
# -------------------------------
# loss: 127.235359  [    0/   30]
# Epoch 159
# -------------------------------
# loss: 187.157333  [    0/   30]
# Epoch 160
# -------------------------------
# loss: 122.371567  [    0/   30]
# Epoch 161
# -------------------------------
# loss: 124.754288  [    0/   30]
# Epoch 162
# -------------------------------
# loss: 126.949677  [    0/   30]
# Epoch 163
# -------------------------------
# loss: 168.764023  [    0/   30]
# Epoch 164
# -------------------------------
# loss: 132.394135  [    0/   30]
# Epoch 165
# -------------------------------
# loss: 149.616287  [    0/   30]
# Epoch 166
# -------------------------------
# loss: 120.402992  [    0/   30]
# Epoch 167
# -------------------------------
# loss: 120.604752  [    0/   30]
# Epoch 168
# -------------------------------
# loss: 74.420898  [    0/   30]
# Epoch 169
# -------------------------------
# loss: 82.177589  [    0/   30]
# Epoch 170
# -------------------------------
# loss: 73.720154  [    0/   30]
# Epoch 171
# -------------------------------
# loss: 108.956139  [    0/   30]
# Epoch 172
# -------------------------------
# loss: 117.565361  [    0/   30]
# Epoch 173
# -------------------------------
# loss: 107.486168  [    0/   30]
# Epoch 174
# -------------------------------
# loss: 93.042297  [    0/   30]
# Epoch 175
# -------------------------------
# loss: 98.343102  [    0/   30]
# Epoch 176
# -------------------------------
# loss: 60.537880  [    0/   30]
# Epoch 177
# -------------------------------
# loss: 60.925892  [    0/   30]
# Epoch 178
# -------------------------------
# loss: 88.492790  [    0/   30]
# Epoch 179
# -------------------------------
# loss: 75.275932  [    0/   30]
# Epoch 180
# -------------------------------
# loss: 65.603920  [    0/   30]
# Epoch 181
# -------------------------------
# loss: 85.531487  [    0/   30]
# Epoch 182
# -------------------------------
# loss: 58.004810  [    0/   30]
# Epoch 183
# -------------------------------
# loss: 50.579453  [    0/   30]
# Epoch 184
# -------------------------------
# loss: 77.543015  [    0/   30]
# Epoch 185
# -------------------------------
# loss: 83.330032  [    0/   30]
# Epoch 186
# -------------------------------
# loss: 87.863518  [    0/   30]
# Epoch 187
# -------------------------------
# loss: 74.545609  [    0/   30]
# Epoch 188
# -------------------------------
# loss: 101.636589  [    0/   30]
# Epoch 189
# -------------------------------
# loss: 69.295982  [    0/   30]
# Epoch 190
# -------------------------------
# loss: 68.267281  [    0/   30]
# Epoch 191
# -------------------------------
# loss: 71.042236  [    0/   30]
# Epoch 192
# -------------------------------
# loss: 71.579994  [    0/   30]
# Epoch 193
# -------------------------------
# loss: 61.544582  [    0/   30]
# Epoch 194
# -------------------------------
# loss: 67.164253  [    0/   30]
# Epoch 195
# -------------------------------
# loss: 59.620861  [    0/   30]
# Epoch 196
# -------------------------------
# loss: 76.014603  [    0/   30]
# Epoch 197
# -------------------------------
# loss: 68.809113  [    0/   30]
# Epoch 198
# -------------------------------
# loss: 59.614910  [    0/   30]
# Epoch 199
# -------------------------------
# loss: 53.587200  [    0/   30]
# Epoch 200
# -------------------------------
# loss: 58.089371  [    0/   30]
# Epoch 201
# -------------------------------
# loss: 38.154034  [    0/   30]
# Epoch 202
# -------------------------------
# loss: 50.747662  [    0/   30]
# Epoch 203
# -------------------------------
# loss: 57.269756  [    0/   30]
# Epoch 204
# -------------------------------
# loss: 48.528790  [    0/   30]
# Epoch 205
# -------------------------------
# loss: 59.588169  [    0/   30]
# Epoch 206
# -------------------------------
# loss: 42.309582  [    0/   30]
# Epoch 207
# -------------------------------
# loss: 53.284504  [    0/   30]
# Epoch 208
# -------------------------------
# loss: 44.774433  [    0/   30]
# Epoch 209
# -------------------------------
# loss: 31.523918  [    0/   30]
# Epoch 210
# -------------------------------
# loss: 23.409542  [    0/   30]
# Epoch 211
# -------------------------------
# loss: 38.462955  [    0/   30]
# Epoch 212
# -------------------------------
# loss: 37.673363  [    0/   30]
# Epoch 213
# -------------------------------
# loss: 24.146061  [    0/   30]
# Epoch 214
# -------------------------------
# loss: 29.016329  [    0/   30]
# Epoch 215
# -------------------------------
# loss: 33.137383  [    0/   30]
# Epoch 216
# -------------------------------
# loss: 32.356247  [    0/   30]
# Epoch 217
# -------------------------------
# loss: 39.107693  [    0/   30]
# Epoch 218
# -------------------------------
# loss: 30.700403  [    0/   30]
# Epoch 219
# -------------------------------
# loss: 33.514988  [    0/   30]
# Epoch 220
# -------------------------------
# loss: 22.614134  [    0/   30]
# Epoch 221
# -------------------------------
# loss: 14.220181  [    0/   30]
# Epoch 222
# -------------------------------
# loss: 27.308023  [    0/   30]
# Epoch 223
# -------------------------------
# loss: 27.132803  [    0/   30]
# Epoch 224
# -------------------------------
# loss: 19.896832  [    0/   30]
# Epoch 225
# -------------------------------
# loss: 26.485123  [    0/   30]
# Epoch 226
# -------------------------------
# loss: 32.244812  [    0/   30]
# Epoch 227
# -------------------------------
# loss: 25.092936  [    0/   30]
# Epoch 228
# -------------------------------
# loss: 24.957237  [    0/   30]
# Epoch 229
# -------------------------------
# loss: 22.722164  [    0/   30]
# Epoch 230
# -------------------------------
# loss: 21.235788  [    0/   30]
# Epoch 231
# -------------------------------
# loss: 31.076891  [    0/   30]
# Epoch 232
# -------------------------------
# loss: 19.216938  [    0/   30]
# Epoch 233
# -------------------------------
# loss: 20.134123  [    0/   30]
# Epoch 234
# -------------------------------
# loss: 18.998713  [    0/   30]
# Epoch 235
# -------------------------------
# loss: 18.354195  [    0/   30]
# Epoch 236
# -------------------------------
# loss: 18.052580  [    0/   30]
# Epoch 237
# -------------------------------
# loss: 24.754936  [    0/   30]
# Epoch 238
# -------------------------------
# loss: 15.143315  [    0/   30]
# Epoch 239
# -------------------------------
# loss: 23.009899  [    0/   30]
# Epoch 240
# -------------------------------
# loss: 14.984923  [    0/   30]
# Epoch 241
# -------------------------------
# loss: 13.315216  [    0/   30]
# Epoch 242
# -------------------------------
# loss: 14.814220  [    0/   30]
# Epoch 243
# -------------------------------
# loss: 13.164670  [    0/   30]
# Epoch 244
# -------------------------------
# loss: 15.210101  [    0/   30]
# Epoch 245
# -------------------------------
# loss: 12.957750  [    0/   30]
# Epoch 246
# -------------------------------
# loss: 11.874253  [    0/   30]
# Epoch 247
# -------------------------------
# loss: 15.619749  [    0/   30]
# Epoch 248
# -------------------------------
# loss: 12.071293  [    0/   30]
# Epoch 249
# -------------------------------
# loss: 9.803474  [    0/   30]
# Epoch 250
# -------------------------------
# loss: 6.616433  [    0/   30]
# Epoch 251
# -------------------------------
# loss: 10.339004  [    0/   30]
# Epoch 252
# -------------------------------
# loss: 9.602536  [    0/   30]
# Epoch 253
# -------------------------------
# loss: 8.933268  [    0/   30]
# Epoch 254
# -------------------------------
# loss: 11.512486  [    0/   30]
# Epoch 255
# -------------------------------
# loss: 8.729049  [    0/   30]
# Epoch 256
# -------------------------------
# loss: 6.194354  [    0/   30]
# Epoch 257
# -------------------------------
# loss: 7.564000  [    0/   30]
# Epoch 258
# -------------------------------
# loss: 6.731240  [    0/   30]
# Epoch 259
# -------------------------------
# loss: 8.512015  [    0/   30]
# Epoch 260
# -------------------------------
# loss: 6.778080  [    0/   30]
# Epoch 261
# -------------------------------
# loss: 5.608490  [    0/   30]
# Epoch 262
# -------------------------------
# loss: 5.569522  [    0/   30]
# Epoch 263
# -------------------------------
# loss: 5.789952  [    0/   30]
# Epoch 264
# -------------------------------
# loss: 6.305234  [    0/   30]
# Epoch 265
# -------------------------------
# loss: 4.897088  [    0/   30]
# Epoch 266
# -------------------------------
# loss: 4.637273  [    0/   30]
# Epoch 267
# -------------------------------
# loss: 2.462911  [    0/   30]
# Epoch 268
# -------------------------------
# loss: 3.925869  [    0/   30]
# Epoch 269
# -------------------------------
# loss: 5.307154  [    0/   30]
# Epoch 270
# -------------------------------
# loss: 3.480992  [    0/   30]
# Epoch 271
# -------------------------------
# loss: 3.535874  [    0/   30]
# Epoch 272
# -------------------------------
# loss: 2.486314  [    0/   30]
# Epoch 273
# -------------------------------
# loss: 2.419331  [    0/   30]
# Epoch 274
# -------------------------------
# loss: 1.911200  [    0/   30]
# Epoch 275
# -------------------------------
# loss: 1.947101  [    0/   30]
# Epoch 276
# -------------------------------
# loss: 2.379246  [    0/   30]
# Epoch 277
# -------------------------------
# loss: 2.302094  [    0/   30]
# Epoch 278
# -------------------------------
# loss: 2.217946  [    0/   30]
# Epoch 279
# -------------------------------
# loss: 1.956044  [    0/   30]
# Epoch 280
# -------------------------------
# loss: 1.275980  [    0/   30]
# Epoch 281
# -------------------------------
# loss: 2.350069  [    0/   30]
# Epoch 282
# -------------------------------
# loss: 1.651430  [    0/   30]
# Epoch 283
# -------------------------------
# loss: 1.340975  [    0/   30]
# Epoch 284
# -------------------------------
# loss: 2.038316  [    0/   30]
# Epoch 285
# -------------------------------
# loss: 0.927100  [    0/   30]
# Epoch 286
# -------------------------------
# loss: 1.245033  [    0/   30]
# Epoch 287
# -------------------------------
# loss: 1.205201  [    0/   30]
# Epoch 288
# -------------------------------
# loss: 0.661372  [    0/   30]
# Epoch 289
# -------------------------------
# loss: 1.075540  [    0/   30]
# Epoch 290
# -------------------------------
# loss: 0.968521  [    0/   30]
# Epoch 291
# -------------------------------
# loss: 1.024895  [    0/   30]
# Epoch 292
# -------------------------------
# loss: 0.984833  [    0/   30]
# Epoch 293
# -------------------------------
# loss: 0.813770  [    0/   30]
# Epoch 294
# -------------------------------
# loss: 0.931689  [    0/   30]
# Epoch 295
# -------------------------------
# loss: 0.383581  [    0/   30]
# Epoch 296
# -------------------------------
# loss: 0.674206  [    0/   30]
# Epoch 297
# -------------------------------
# loss: 0.561774  [    0/   30]
# Epoch 298
# -------------------------------
# loss: 0.476762  [    0/   30]
# Epoch 299
# -------------------------------
# loss: 0.590278  [    0/   30]
# Epoch 300
# -------------------------------
# loss: 0.478631  [    0/   30]
# Epoch 301
# -------------------------------
# loss: 0.658917  [    0/   30]
# Epoch 302
# -------------------------------
# loss: 0.321724  [    0/   30]
# Epoch 303
# -------------------------------
# loss: 0.258703  [    0/   30]
# Epoch 304
# -------------------------------
# loss: 0.377924  [    0/   30]
# Epoch 305
# -------------------------------
# loss: 0.274574  [    0/   30]
# Epoch 306
# -------------------------------
# loss: 0.216917  [    0/   30]
# Epoch 307
# -------------------------------
# loss: 0.234787  [    0/   30]
# Epoch 308
# -------------------------------
# loss: 0.215716  [    0/   30]
# Epoch 309
# -------------------------------
# loss: 0.209777  [    0/   30]
# Epoch 310
# -------------------------------
# loss: 0.131309  [    0/   30]
# Epoch 311
# -------------------------------
# loss: 0.157592  [    0/   30]
# Epoch 312
# -------------------------------
# loss: 0.148347  [    0/   30]
# Epoch 313
# -------------------------------
# loss: 0.214826  [    0/   30]
# Epoch 314
# -------------------------------
# loss: 0.124704  [    0/   30]
# Epoch 315
# -------------------------------
# loss: 0.115586  [    0/   30]
# Epoch 316
# -------------------------------
# loss: 0.094549  [    0/   30]
# Epoch 317
# -------------------------------
# loss: 0.087621  [    0/   30]
# Epoch 318
# -------------------------------
# loss: 0.074264  [    0/   30]
# Epoch 319
# -------------------------------
# loss: 0.065411  [    0/   30]
# Epoch 320
# -------------------------------
# loss: 0.054721  [    0/   30]
# Epoch 321
# -------------------------------
# loss: 0.061005  [    0/   30]
# Epoch 322
# -------------------------------
# loss: 0.047886  [    0/   30]
# Epoch 323
# -------------------------------
# loss: 0.041655  [    0/   30]
# Epoch 324
# -------------------------------
# loss: 0.032766  [    0/   30]
# Epoch 325
# -------------------------------
# loss: 0.029309  [    0/   30]
# Epoch 326
# -------------------------------
# loss: 0.032681  [    0/   30]
# Epoch 327
# -------------------------------
# loss: 0.018826  [    0/   30]
# Epoch 328
# -------------------------------
# loss: 0.023234  [    0/   30]
# Epoch 329
# -------------------------------
# loss: 0.018304  [    0/   30]
# Epoch 330
# -------------------------------
# loss: 0.016937  [    0/   30]
# Epoch 331
# -------------------------------
# loss: 0.014142  [    0/   30]
# Epoch 332
# -------------------------------
# loss: 0.022013  [    0/   30]
# Epoch 333
# -------------------------------
# loss: 0.010883  [    0/   30]
# Epoch 334
# -------------------------------
# loss: 0.004362  [    0/   30]
# Epoch 335
# -------------------------------
# loss: 0.007664  [    0/   30]
# Epoch 336
# -------------------------------
# loss: 0.007018  [    0/   30]
# Epoch 337
# -------------------------------
# loss: 0.006673  [    0/   30]
# Epoch 338
# -------------------------------
# loss: 0.005951  [    0/   30]
# Epoch 339
# -------------------------------
# loss: 0.004171  [    0/   30]
# Epoch 340
# -------------------------------
# loss: 0.003713  [    0/   30]
# Epoch 341
# -------------------------------
# loss: 0.004831  [    0/   30]
# Epoch 342
# -------------------------------
# loss: 0.002842  [    0/   30]
# Epoch 343
# -------------------------------
# loss: 0.002379  [    0/   30]
# Epoch 344
# -------------------------------
# loss: 0.002111  [    0/   30]
# Epoch 345
# -------------------------------
# loss: 0.001834  [    0/   30]
# Epoch 346
# -------------------------------
# loss: 0.001448  [    0/   30]
# Epoch 347
# -------------------------------
# loss: 0.001160  [    0/   30]
# Epoch 348
# -------------------------------
# loss: 0.001028  [    0/   30]
# Epoch 349
# -------------------------------
# loss: 0.000789  [    0/   30]
# Epoch 350
# -------------------------------
# loss: 0.000539  [    0/   30]
# Epoch 351
# -------------------------------
# loss: 0.000573  [    0/   30]
# Epoch 352
# -------------------------------
# loss: 0.000310  [    0/   30]
# Epoch 353
# -------------------------------
# loss: 0.000437  [    0/   30]
# Epoch 354
# -------------------------------
# loss: 0.000323  [    0/   30]
# Epoch 355
# -------------------------------
# loss: 0.000087  [    0/   30]
# Epoch 356
# -------------------------------
# loss: 0.000212  [    0/   30]
# Epoch 357
# -------------------------------
# loss: 0.000159  [    0/   30]
# Epoch 358
# -------------------------------
# loss: 0.000138  [    0/   30]
# Epoch 359
# -------------------------------
# loss: 0.000117  [    0/   30]
# Epoch 360
# -------------------------------
# loss: 0.000123  [    0/   30]
# Epoch 361
# -------------------------------
# loss: 0.000077  [    0/   30]
# Epoch 362
# -------------------------------
# loss: 0.000055  [    0/   30]
# Epoch 363
# -------------------------------
# loss: 0.000054  [    0/   30]
# Epoch 364
# -------------------------------
# loss: 0.000035  [    0/   30]
# Epoch 365
# -------------------------------
# loss: 0.000023  [    0/   30]
# Epoch 366
# -------------------------------
# loss: 0.000021  [    0/   30]
# Epoch 367
# -------------------------------
# loss: 0.000020  [    0/   30]
# Epoch 368
# -------------------------------
# loss: 0.000013  [    0/   30]
# Epoch 369
# -------------------------------
# loss: 0.000010  [    0/   30]
# Epoch 370
# -------------------------------
# loss: 0.000008  [    0/   30]
# Epoch 371
# -------------------------------
# loss: 0.000003  [    0/   30]
# Epoch 372
# -------------------------------
# loss: 0.000005  [    0/   30]
# Epoch 373
# -------------------------------
# loss: 0.000004  [    0/   30]
# Epoch 374
# -------------------------------
# loss: 0.000003  [    0/   30]
# Epoch 375
# -------------------------------
# loss: 0.000002  [    0/   30]
# Epoch 376
# -------------------------------
# loss: 0.000002  [    0/   30]
# Epoch 377
# -------------------------------
# loss: 0.000001  [    0/   30]
# Epoch 378
# -------------------------------
# loss: 0.000001  [    0/   30]
# Epoch 379
# -------------------------------
# loss: 0.000001  [    0/   30]
# Epoch 380
# -------------------------------
# loss: 0.000001  [    0/   30]
# Epoch 381
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 382
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 383
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 384
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 385
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 386
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 387
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 388
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 389
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 390
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 391
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 392
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 393
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 394
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 395
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 396
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 397
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 398
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 399
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 400
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 401
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 402
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 403
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 404
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 405
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 406
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 407
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 408
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 409
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 410
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 411
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 412
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 413
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 414
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 415
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 416
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 417
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 418
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 419
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 420
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 421
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 422
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 423
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 424
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 425
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 426
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 427
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 428
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 429
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 430
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 431
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 432
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 433
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 434
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 435
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 436
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 437
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 438
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 439
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 440
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 441
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 442
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 443
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 444
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 445
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 446
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 447
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 448
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 449
# -------------------------------
# loss: 0.000000  [    0/   30]
# Epoch 450
# -------------------------------
# loss: 0.000000  [    0/   30]
# Done!

# %%
def c_to_f(c):
  return 9/5 * c + 32

# %%
Temp_C = [0, 15, 35] # 32, 59, 95

for c in Temp_C:
  with torch.no_grad():
    model.eval()
    Temp_F = model(torch.tensor([np.float32(c)]))  
    print(f'C {c} = F {np.around(Temp_F[0])}')
# Out:
# C 0 = F 32.0
# C 15 = F 59.0
# C 35 = F 95.0

# %%
for c in Temp_C:
  print(f'C {c} = F {c_to_f(c)}')
# Out:
# C 0 = F 32.0
# C 15 = F 59.0
# C 35 = F 95.0

# %%
s = torch.sum(model.layer_1[0].weight.data)
s # 9/5 = 1.8
# Out:
# tensor(1.8000)

# %%
s = torch.sum(model.layer_1[0].bias.data)
s # 32
# Out:
# tensor(32.0000)
